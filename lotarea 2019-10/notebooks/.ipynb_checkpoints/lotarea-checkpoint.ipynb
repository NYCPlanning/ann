# %%
import pandas as pd
from pandas.io import sql
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
from matplotlib import rcParams
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import os
import dotenv
import seaborn as sns
import csv
import numpy as np

# %matplotlib inline

# %%
# %load_ext dotenv
# %dotenv ../.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
cnx = create_engine(os.getenv('EDMDB'))

# %% [markdown]
# Get a count of records that have a lot area of zero

# %%
pd.read_sql_query('''
SELECT COUNT(*) AS lotarea_zero_count
FROM dcp.pluto192_before_corr
WHERE "LotArea" = 0;
''', cnx)
# Out:
#    lotarea_zero_count
# 0                2101

# %% [markdown]
# Create a breakout report by building class, with lotarea, shape_area, and the difference between them. Casting large numbers to integers for readability.

# %%
pd.read_sql_query('''
SELECT p."BldgClass",
    SUM(p."LotArea") AS old_lotarea,
    CAST(SUM(ROUND(p."Shape_Area")) AS INTEGER) AS new_lotarea,
    CAST(SUM(p."Shape_Area"::numeric - ROUND(p."LotArea"::numeric)) AS INTEGER) AS difference
   FROM dcp.pluto192_before_corr p
  GROUP BY p."BldgClass"
  ORDER BY p."BldgClass";
''', cnx)
# Out:
#     BldgClass  old_lotarea  new_lotarea  difference
# 0          A0   37885163.0     38106775    221620.0
# 1          A1  479167463.0    482410453   3243121.0
# 2          A2  207612923.0    209106612   1493833.0
# 3          A3   64054396.0     63769143   -285239.0
# 4          A4    8556706.0      8771364    214667.0
# ..        ...          ...          ...         ...
# 211        Z5     676101.0       671442     -4659.0
# 212        Z7    7250218.0     17886905  10636690.0
# 213        Z8  165608245.0    183349052  17740807.0
# 214        Z9   68507688.0     59135476  -9372208.0
# 215      None          NaN      6531315         NaN
#
# [216 rows x 4 columns]

# %% [markdown]
# Breakout report by land use code. Casting large numbers to integers for readability. Save as a dataframe for charting.

# %%
landuse_breakout = pd.read_sql_query('''
SELECT p."LandUse",
    d.def as "LandUse Definition",
    SUM(p."LotArea") AS old_lotarea,
    CAST(SUM(ROUND(p."Shape_Area")) AS INTEGER) AS new_lotarea,
    CAST(SUM(p."Shape_Area"::numeric - ROUND(p."LotArea"::numeric)) AS INTEGER) AS difference
   FROM dcp.pluto192_before_corr p,
       dcp.landuse_definitions d
  WHERE d.landuse = p."LandUse"
  GROUP BY p."LandUse", d.def
  ORDER BY (SUM(p."Shape_Area"::numeric - ROUND(p."LotArea"::numeric))) DESC;
''', cnx)
landuse_breakout
# Out:
#    LandUse                  LandUse Definition  old_lotarea  new_lotarea  \
# 0       07          Transportation and Utility    490841651    574068931
# 1       01        One and Two Family Buildings   1827684793   1842664419
# 2       02       Multi-Family Walkup Buildings    477401193    486265363
# 3       04    Mixed Residential and Commercial    246226680    252276123
# 4       05               Commercial and Office    272108523    275625746
# 5       03     Multi-Family Elevator Buildings    347675383    349975465
# 6       10                  Parking Facilities     86054314     86904411
# 7       06        Industrial and Manufacturing    228108881    218929731
# 8       08  Public Facilities and Institutions    534900031    517012228
# 9       11                         Vacant Land    555829858    349992991
# 10      09   Open Space and Outdoor Recreation   1613283238   1281417518
#
#     difference
# 0     83227290
# 1     14979882
# 2      8864185
# 3      6049619
# 4      3517244
# 5      2300090
# 6       850113
# 7     -9179136
# 8    -17887824
# 9   -205836797
# 10  -331865688

# %% [markdown]
# Breakout report by Borough. Casting large numbers to BIGINT.

# %%
pd.read_sql_query('''
SELECT p."Borough",
    SUM(p."LotArea") AS old_lotarea,
    CAST(SUM(ROUND(p."Shape_Area")) AS BIGINT) AS new_lotarea,
    CAST(SUM(p."Shape_Area"::numeric - ROUND(p."LotArea"::numeric)) AS BIGINT) AS difference
   FROM dcp.pluto192_before_corr p
  GROUP BY p."Borough"
  ORDER BY p."Borough";
''', cnx)
# Out:
#   Borough  old_lotarea  new_lotarea  difference
# 0      BK   1663660298   1415454431  -249555019
# 1      BX    911762872    877016457   -35690346
# 2      MN    494219347    454317296   -40097914
# 3      QN   2364371325   2278631388   -88556471
# 4      SI   1322005773   1293423808   -29807195

# %% [markdown]
# Overall totals

# %%
pd.read_sql_query('''
SELECT SUM(p."LotArea") AS old_lotarea,
    CAST(SUM(ROUND(p."Shape_Area")) AS BIGINT) AS new_lotarea,
    CAST(SUM(p."Shape_Area"::numeric - ROUND(p."LotArea"::numeric)) AS BIGINT) AS difference
   FROM dcp.pluto192_before_corr p;
''', cnx)
# Out:
#    old_lotarea  new_lotarea  difference
# 0   6756019615   6318843380  -443706944

# %% [markdown]
# Settings for bar chart

# %%
sns.set()

SMALL_SIZE = 8
MEDIUM_SMALL_SIZE = 10
MEDIUM_SIZE = 11
MEDIUM_LARGE_SIZE = 14
BIGGER_SIZE = 16

rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Inconsolata']
plt.rc('font', size=SMALL_SIZE)
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_LARGE_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# Bar chart by landuse code

# %%
def y_fmt(tick_val, pos):
    if tick_val > 1000000000:
        val = round(int(tick_val) /1000000000, 1)
        return '{}B'.format(val)
    elif tick_val > 1000000:
        val = round(int(tick_val) /1000000)
        return '{}M'.format(val)
    elif tick_val > 1000:
        val = int(tick_val) / 1000
        return '{}k'.format(val)
    else:
        return tick_val

landuse = []
lotarea = []
old_lotarea = []
new_lotarea = []

for ind in landuse_breakout.index: 
    landuse.append(landuse_breakout['LandUse Definition'][ind])
    old_lotarea.append(int(landuse_breakout['old_lotarea'][ind]))
    new_lotarea.append(int(landuse_breakout['new_lotarea'][ind]))

width = 0.4
r1 = np.arange(len(landuse))

f = plt.figure(figsize=(16,12))
ax = f.add_subplot(111)
ax.bar(r1, old_lotarea, width, color='#0080ff', align='center', label='Before Correction')
ax.bar(r1+width, new_lotarea, width, color='#ff7e00', align='center', label='After Correction')
ax.ticklabel_format(useOffset=False, style='plain')
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))

plt.xlabel('Land Use', fontweight='bold')
plt.ylabel('Total Lot Area', fontweight='bold', labelpad=10)
plt.title('Lot Area by Land Use Code: PLUTO 19v2', fontweight='bold', pad=10)
plt.tick_params(bottom=True, left=True)
plt.xticks(rotation=90)
plt.xticks(r1 + width / 2, landuse)
plt.yticks(np.arange(100000000, 2000000000, 200000000))
plt.legend(loc='upper right', shadow='bool')
legend = plt.legend()
frame = legend.get_frame()
frame.set_facecolor('white')
plt.show()
